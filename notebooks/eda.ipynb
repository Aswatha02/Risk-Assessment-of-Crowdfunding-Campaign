# %%
import pandas as pd
df = pd.read_csv('../data/raw/kickstarter_data_full.csv')
# Out:
# C:\Users\jelen\AppData\Local\Temp\ipykernel_25712\2388392334.py:2: DtypeWarning: Columns (29,30,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../data/raw/kickstarter_data_full.csv')
